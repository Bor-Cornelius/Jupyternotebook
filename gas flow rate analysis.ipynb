# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df =pd.read_csv('20220421 flow rates.csv')
df.head(5)
# Out:
#    customer   gas_used  cooking_time received_on  gramsperminute  \
# 0     10912   1.120117      0.016667  21/04/2022       67.207031
# 1    420439   0.040039      0.016667  21/04/2022        2.402344
# 2    133140   0.140137      0.016667  20/04/2022        8.408203
# 3   1325009  30.660156      0.016667  20/04/2022     1839.609375
# 4     45694   0.149414      0.033333  21/04/2022        4.482422
#
#                   Flowrate
# 0  Above 10 gramsperminute
# 1  Within normal flow rate
# 2  Within normal flow rate
# 3  Above 10 gramsperminute
# 4  Within normal flow rate

# %%
fig = plt.figure()
sns.scatterplot(data=df,x="cooking_time",y="gas_used",hue="Flowrate",size="Flowrate",sizes=(10,15))
# Out:
# <AxesSubplot:xlabel='cooking_time', ylabel='gas_used'>

# %%
df2 =pd.read_csv('Flow rate analysis.csv')
df2.head(5)
# Out:
#    customer   gas_used  cooking_time received_on  gramsperminute  \
# 0   1665749  697.01170    143.300000     29:21.0        4.864004
# 1    482190  606.92970    134.233333     01:42.0        4.521453
# 2    164094  549.58203    102.166667     45:26.0        5.379269
# 3    695152  545.20000    140.716667     40:41.0        3.874452
# 4    659410  534.58010    104.183333     09:06.0        5.131148
#
#                   Flowrate
# 0  Within normal flow rate
# 1  Within normal flow rate
# 2  Within normal flow rate
# 3  Within normal flow rate
# 4  Within normal flow rate

# %%
df2.describe()
# Out:
#            customer       gas_used   cooking_time  gramsperminute
# count  9.994320e+05  999432.000000  999432.000000   999432.000000
# mean   2.831012e+06      25.258800      11.807561        2.149068
# std    3.117285e+06      29.615568      13.352770        2.172309
# min    1.473000e+03       0.019531       0.016667        0.013094
# 25%    4.170490e+05       5.740234       2.716667        1.634811
# 50%    1.025935e+06      15.240234       7.166667        2.152045
# 75%    5.271856e+06      34.000000      15.950000        2.563745
# max    9.999924e+06     697.011700     143.300000     1839.609375

# %%
fig2 = plt.figure()
sns.scatterplot(data=df2,x="cooking_time",y="gas_used",hue="Flowrate",size="Flowrate",sizes=(10,15))
# Out:
# <AxesSubplot:xlabel='cooking_time', ylabel='gas_used'>
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
